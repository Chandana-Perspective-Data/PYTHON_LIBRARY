# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
xpoints=np.array([1,7])
ypoints=np.array([0,8])
plt.plot(xpoints,ypoints)
plt.show()

# %%
# Plotting Without Line
#To plot only the markers, you can use shortcut string notation parameter 'o', 
#which means 'rings'.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([0,10])
plt.plot(xpoints,ypoints,"o")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([2,4,6,8,3])
ypoints=np.array([1,3,5,10,1])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# # Default X-Points
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
ypoints=np.array([3,8,7,1,10,25])
plt.plot(ypoints)
plt.show()

# %%
ypoints=np.array([3,5,8,1,10])
plt.plot(ypoints,marker="o")
plt.show()

# %%
plt.plot(ypoints,marker="*")

# %%
plt.plot(ypoints,marker="+")

# %%
ypoints=np.array([2,4,12,8,10,2])
plt.plot(ypoints,marker="o") # circle
plt.show()

# %%
plt.plot(ypoints,marker="*") # star

# %%
plt.plot(ypoints,marker=".") # point

# %%
plt.plot(ypoints,marker=",") # pixel

# %%
plt.plot(ypoints,marker="x")# x

# %%
plt.plot(ypoints,marker="X") #X (filled)

# %%
plt.plot(ypoints,marker="+")# plus

# %%
plt.plot(ypoints,marker="P")# PLUS (FILLED)

# %%
plt.plot(ypoints,marker="s")# square

# %%
plt.plot(ypoints,marker="D")# DIAMOND

# %%
plt.plot(ypoints,marker="d")# daimond

# %%
plt.plot(ypoints,marker="p")# pentagon

# %%
plt.plot(ypoints,marker="H")# HEXAGON

# %%
plt.plot(ypoints,marker="h")

# %%
plt.plot(ypoints,marker="^")# triangle up

# %%
plt.plot(ypoints,marker="v")# traingle down

# %%
plt.plot(ypoints,marker="<")# triangle left

# %%
plt.plot(ypoints,marker=">")# triangle right

# %%
plt.plot(ypoints,marker="1")#tri down

# %%
plt.plot(ypoints,marker="2")# trip up

# %%
plt.plot(ypoints,marker="_")

# %%
plt.plot(ypoints,marker="v")

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])# solid line

plt.plot(ypoints, 'o-')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10]) # dotted line

plt.plot(ypoints, 'o:')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10]) # dashed line

plt.plot(ypoints, 'o--')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10]) # dashed line

plt.plot(ypoints, 'o-.')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10]) # marker size

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10]) # marker color

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()
